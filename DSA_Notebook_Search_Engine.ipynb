# %% [markdown]
# # This exercise is to use whoosh to build a search engine
# # over your own DSA Notebooks
#
# Have you ever had the thought:
# "I know we did this before! Where did I see that in the course materials?"
#
# This exercise is to build a technical solution to aid in answering that question.
#
# **NOTE:** This is a little more like a practice, but it is the exercise for the week.
#
# ## Here are the steps
# ### I) Build (conceptual):
#   1. Crawl through your home directory and find all notebooks (`.ipynb`)
#   2. Extract the visible text from the notebooks
#   3. Use Whoosh to Index
#
# ### II) Query:
#   1. Open the index
#   1. Query

# %% [markdown]
# ---
# ## Preliminaries
# ### Parsing Visible Text from a notebook

# %%
import sys
import json

# Test on my self, like all evil scientists
filename = './DSA_Notebook_Search_Engine.ipynb'

# Use the JSON library to get it in a DOM-like structure
# This is similar to using BeautifulSoup on HTML/KML/XML
file_data = json.load(open(filename))

# File data is now a map, recall a JSON format is a combo of dictionaries and lists
cells = file_data.get('cells')

print("Dumping {} Non-output Cells from {}".format(len(cells), filename))

# Count the Cells
cno = 1

# for each cell in the notebook
for c in cells:
    
    #extract and test the cell type
    cell_type = c['cell_type']
    if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
        print("# -------------{}----------------".format(cno))
        print("**********************JACKY: CELL TYPE = ", cell_type)
        # run the source into lines, it is actually a list of strings/lines
        source = c['source']
        for l in source:
            print(l.strip('\n'))
        cno += 1
# Out:
# Dumping 30 Non-output Cells from ./DSA_Notebook_Search_Engine.ipynb
# # -------------1----------------
# **********************JACKY: CELL TYPE =  markdown
# # This exercise is to use whoosh to build a search engine
# # over your own DSA Notebooks
#
# Have you ever had the thought:
# "I know we did this before! Where did I see that in the course materials?"
#
# This exercise is to build a technical solution to aid in answering that question.
#
# **NOTE:** This is a little more like a practice, but it is the exercise for the week.
#
# ## Here are the steps
# ### I) Build (conceptual):
#   1. Crawl through your home directory and find all notebooks (`.ipynb`)
#   2. Extract the visible text from the notebooks
#   3. Use Whoosh to Index
#
# ### II) Query:
#   1. Open the index
#   1. Query
# # -------------2----------------
# **********************JACKY: CELL TYPE =  markdown
# ---
# ## Preliminaries
# ### Parsing Visible Text from a notebook
# # -------------3----------------
# **********************JACKY: CELL TYPE =  code
# import sys
# import json
#
# # Test on my self, like all evil scientists
# filename = './DSA_Notebook_Search_Engine.ipynb'
#
# # Use the JSON library to get it in a DOM-like structure
# # This is similar to using BeautifulSoup on HTML/KML/XML
# file_data = json.load(open(filename))
#
# # File data is now a map, recall a JSON format is a combo of dictionaries and lists
# cells = file_data.get('cells')
#
# print("Dumping {} Non-output Cells from {}".format(len(cells), filename))
#
# # Count the Cells
# cno = 1
#
# # for each cell in the notebook
# for c in cells:
#
#     #extract and test the cell type
#     cell_type = c['cell_type']
#     if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
#         print("# -------------{}----------------".format(cno))
#         print("**********************JACKY: CELL TYPE = ", cell_type)
#         # run the source into lines, it is actually a list of strings/lines
#         source = c['source']
#         for l in source:
#             print(l.strip('\n'))
#         cno += 1
# # -------------4----------------
# **********************JACKY: CELL TYPE =  markdown
# If you have followed the pattern of the way Dr. Scott builds up code...
#
# ## a) Time to create function!
#
# ### Your function should return a set of cells, each cell having all
# ### lines concatentated into one long `string` of data.
#
# The comment lines, `# TODO ... `, will define steps for you to complete.
# # -------------5----------------
# **********************JACKY: CELL TYPE =  code
# def visibleTextFromNB(filename):
#     '''
#     # TODO Describe this function's purpose and return result
#
#     This function pulls all the non-output visible cells from
#     a JupyterNotebook and concatenates it all into a block of
#     text.
#
#     Returns : a list of the cells
#     '''
#     #####################################
#     # TODO: Parse file, pull cells
#     #####################################
#
#     file_data = json.load(open(filename))
#     cells = file_data.get('cells')
#
#     #print('Dumping {} Non-output cells from {}'.format(len(cells), filename))
#
#     cno = 1
#     cell_list = []
#
#     for c in cells:
#         cell_type = c['cell_type']
#         if (cell_type == 'code' or cell_type == 'markdown' or cell_type == 'raw'):
#             #print("===========Cell Number: {}======{}========".format(cno, cell_type))
#
#             source = c["source"]
#             textBlock = ""
#
#             for l in source:
#                 textBlock += l
#
#             #print("appending # {} : {}".format(len(cell_list), textBlock[0:50]))
#             cell_list.append(textBlock)
#             cno += 1
#
#             if cells == None:
#                 return cell_list
#
#     # return the list
#     return cell_list
#
# #End of function: visibleTextFromNB
# # -------------6----------------
# **********************JACKY: CELL TYPE =  markdown
# ## Test your function:
# # -------------7----------------
# **********************JACKY: CELL TYPE =  code
# #################################
# #        NO EDIT CELL
# #################################
#
# # Use the lab notebook
# filename = '../labs/Text_Search_TFIDF.ipynb'
# cells = visibleTextFromNB(filename)
#
# # Print the begin and end
# print(cells[0])
# print(cells[1])
# print('...')
# print(cells[len(cells)-1])
# # -------------8----------------
# **********************JACKY: CELL TYPE =  markdown
# #### <span style="background:yellow">Expected Output</span>
#
# ```
# # Building and Loading Text Search in Python Whoosh using TFIDF
#
#
# ## OUTLINE
#
#  1. [Task at hand](#task)
#  1. [Buiding our Whoosh Schema](#build_it)
#  1. [Loading Data](#load_it)
#  1. [Scoring](#Scoring)
#  1. [Executing Queries, Google-lite...very very lite](#TFIFD)
# ---
# <a id='task' ></a>
#
# ## Task at hand
#
# For this lab, we are going to revist the IR_with_Python_Whoosh lab in module 5 which walks us through the process of creating full text search capability within Python. In addition to that we are going to incorporate a scoring technique called TFIDF for ranking documents based on TFIDF scores of the terms occuring in the documents.
#
# We will walk through the process to build the search engine in Python using whoosh. We will compare the serach results with and without TFIDF method.
# ...
# The line_num above is the actual line number in the text file. docnum should be the index number in the whole indexes we have created.
# ```
# # -------------9----------------
# **********************JACKY: CELL TYPE =  markdown
# # b) Create a _draft_ function to walk through directory and find notebooks (.ipynb)
#
# Collect up the directory walking code from module 5 examples.
#
# #### Note, the starting folder will be `'~'`, the alias for your home directory
#
# #### Note, do not process files yet, just construct the function and print the notebook path names
# # -------------10----------------
# **********************JACKY: CELL TYPE =  code
# import os, os.path
#
# def walkFolder(folder):
#     '''
#     Process a folder for files and subfolders
#     Prints the files and folders that are processed.
#     '''
#     # print('Processing folder: ', folder)
#
#     #####################################
#     # TODO: walk through the filesystem starting at folder
#     # HINT: os.walk
#     #####################################
#
#     for root, dirs, files in os.walk(folder):
#         # print("root = ", root)
#
#         #####################################
#         # TODO: Process Files
#         # HINT: skips file.endswith("-checkpoint.ipynb")
#         #####################################
#
#         for file in files:
#             if (file.endswith(".ipynb") \
#                 and not file.endswith("-checkpoint.ipynb")):
#                 filename = os.path.join(root, file)
#                 print("Found Notebook: ", filename)
#
#         #####################################
#         # TODO: Recurse into subfolders
#         # HINT: Skip these
#         #           .config
#         #           .cache
#         #           .ssh
#         #           ... etc.
#         #####################################
#
#         for d in dirs:
#             if (d != ".config" \
#                 and d != ".cache" \
#                 and d != ".ssh" \
#                 and d != ".local" \
#                 and d != ".git" \
#                 and d != ".ipython"
#                ):
#                 #print("recursing into :", d)
#                 walkFolder(d)
#
#
# ############# END for walkFolder
# # -------------11----------------
# **********************JACKY: CELL TYPE =  markdown
# ## Test your function:
# # -------------12----------------
# **********************JACKY: CELL TYPE =  code
# #################################
# #        NO EDIT CELL
# #################################
#
# # Use your top-level home directory
# initial_root = os.path.expanduser('~')
#
# walkFolder("/dsa/home/lz6m7")
# # -------------13----------------
# **********************JACKY: CELL TYPE =  markdown
# #### <span style="background:yellow">Expected Output</span>
#
#    * Expected output similar to
#
# ```
# Found Notebook: /dsa/home/scottgs/Testing Python.ipynb
# Found Notebook: /dsa/home/scottgs/Testing R.ipynb
# ...
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/practices/Text_Preprocessing.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/exercises/Exercises_Python_text_search.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/answers/Text_Preprocessing_Answers.ipynb
# ```
# # -------------14----------------
# **********************JACKY: CELL TYPE =  markdown
# # c) Create the schema for whoosh and initialize
# # the index in `notebooks` folder
#
# Recall, in the work above you pulled each visible cell from the notebook into a list of cells.
#
# So, we can store the data such as our results are:
#   * Filename
#   * Cell No.
#
# Then, we will also index the cell content.
# # -------------15----------------
# **********************JACKY: CELL TYPE =  code
# from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
# from whoosh.analysis import StemmingAnalyzer
# from whoosh import index
#
#
# #####################################
# # TODO: Create the schema
# #####################################
# schema = Schema(filename=ID(stored=True),
#                 cell_no=ID(stored=True),
#                 content=TEXT(analyzer=StemmingAnalyzer(), stored=True)
#                )
#
# #####################################
# # TODO: Create the index and initialize a `writer`
# #####################################
# ix = index.create_in("indexes", schema)
# writer = ix.writer()
#
# # -------------16----------------
# **********************JACKY: CELL TYPE =  code
# #################################
# #        NO EDIT CELL
# #################################
#
# #  REPEATED for better review
#
# def visibleTextFromNB(filename):
#     '''
#     # TODO Describe this function's purpose and return result
#     This function pulls all the non-output visible cells from
#     a JupyterNotebook and concatenates it all into a block of
#     text.
#     Returns : a list of the cells
#     '''
#     #####################################
#     # TODO: Parse file, pull cells
#     #####################################
#
#     file_data = json.load(open(filename))
#
#     # File data is now a map, recall a JSON format is a combo of dictionaries and lists
#     cells = file_data.get('cells')
#
#     #####################################
#     # TODO: Append cells into a list of cells
#     # HINT: Do not strip the newline, \n
#     #####################################
#
#     cell_list = []
#     if cells == None:
#         return cell_list
#
#     # for each cell in the notebook
#     for c in cells:
#
#         #extract and test the cell type
#         cell_type = c['cell_type']
#         if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
#             cell_text = ""
#             # run the source into lines, it is actually a list of strings/lines
#             source = c['source']
#             for l in source:
#                 cell_text += l
#             cell_list.append(cell_text)
#
#
#     #####################################
#     # TODO: Append cells into a list of cells
#     # HINT: Do not strip the newline, \n
#     #####################################
#
#     # return the list
#     return cell_list
#
# #End of function: visibleTextFromNB
# # -------------17----------------
# **********************JACKY: CELL TYPE =  markdown
# ## d) Write function to load file into the index
#   * See [Module 5 Lab](../../module5/labs/IR_with_Python_Whoosh.ipynb#This-should-look-familiar!)
# # -------------18----------------
# **********************JACKY: CELL TYPE =  code
# def loadFile(writer, fname):
#     '''
#     Read file contents, load into database.
#     '''
#     #####################################
#     # TODO: Get cell text from function
#     #####################################
#     cells = visibleTextFromNB(fname)
#
#     cellnum = 1
#
#     for c in cells:
#         print("Starting file:", fname , " -- cellnum", cellnum)
#         print("")
#
#         writer.add_document(filename = fname, \
#                             cell_no = str(cellnum), \
#                             content = c)
#         cellnum += 1
#
#     print("")
#     print("Indexed: ", fname)
#     print("==================")
#
# # END of function
# # -------------19----------------
# **********************JACKY: CELL TYPE =  markdown
# # e) Adapt the folder walking function to invoke file load
#
# ### HINT: add the `writer` as a parameter
# # -------------20----------------
# **********************JACKY: CELL TYPE =  code
# import os, os.path
#
# #####################################
# # TODO: Adapt the parameters
# #####################################
# def walkFolder(writer, folder):
#     '''
#     Process a folder for files and subfolders
#     Prints the files and folders that are processed.
#     '''
#     for root, dirs, files in os.walk(folder):
#         # print("root = ", root)
#
#         #####################################
#         # TODO: Process Files
#         # HINT: skips file.endswith("-checkpoint.ipynb")
#         #####################################
#
#         for file in files:
#             if (file.endswith(".ipynb") \
#                 and not file.endswith("-checkpoint.ipynb")):
#                 filename = os.path.join(root, file)
#                 loadFile(writer, filename)
#                 print("Found Notebook: ", filename)
#                 print("")
#
#         #####################################
#         # TODO: Recurse into subfolders
#         # HINT: Skip these
#         #           .config
#         #           .cache
#         #           .ssh
#         #           ... etc.
#         #####################################
#
#         for d in dirs:
#             if (d != ".config" \
#                 and d != ".cache" \
#                 and d != ".ssh" \
#                 and d != ".local" \
#                 and d != ".git" \
#                 and d != ".ipython"
#                ):
#                 #print("recursing into :", d)
#                 walkFolder(writer, d)
#
# ############# END for walkFolder
# # -------------21----------------
# **********************JACKY: CELL TYPE =  markdown
# # f) Run the index build
# # -------------22----------------
# **********************JACKY: CELL TYPE =  code
# #################################
# #        NO EDIT CELL
# #################################
#
# # Use your top-level home directory
# initial_root = os.path.expanduser('~')
# walkFolder(writer,initial_root)
#
#
# # Commit changes
# writer.commit() # save changes
# # -------------23----------------
# **********************JACKY: CELL TYPE =  code
# # DO NOT RUN UNLESS YOU NEED A RESET
#
# # from whoosh import writing
# # writer.commit(mergetype=writing.CLEAR)
# # -------------24----------------
# **********************JACKY: CELL TYPE =  markdown
# # g) Execute three queries
#
# ## 1
# # -------------25----------------
# **********************JACKY: CELL TYPE =  code
# from whoosh.qparser import QueryParser
# from whoosh import scoring
#
# # Get input, convert to unicode
# qstr = input("Input a query: ")
#
# print("searching for ",qstr)
#
# ####################################
# # TODO: Build query parser and parse query
# ####################################
#
# with ix.searcher(weighting = scoring.TF_IDF()) as s:
#     qp = QueryParser("content", ix.schema)
#     user_q = qp.parse(qstr)
#
#     ####################################
#     # TODO: Search the content field
#     ####################################
#
#     results = s.search(user_q)
#     for hit in results:
#         print("cell {} of {}".format(hit["cell_no"], hit["filename"]))
#
#
#
# # -------------26----------------
# **********************JACKY: CELL TYPE =  markdown
# #### <span style="background:yellow">Expected Output</span>
#
#   *  Example output from searching for QueryParser
#
# ```
# Input a qeury: QueryParser
# searching for  QueryParser
# content:queryparser
# Cell 11 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# Cell 27 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/answers/ParsingWikipediaLifeformPage.ipynb'
# Cell 25 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb'
# Cell 9 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 14 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 17 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 45 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Topic_modelling.ipynb'
# Cell 7 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 8 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 11 of Notebook '/dsa/home/scottgs/sp17DMIR/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# ```
#
# ---
# ## 2
# # -------------27----------------
# **********************JACKY: CELL TYPE =  code
# from whoosh.qparser import QueryParser
# from whoosh import scoring
#
# # Get input, convert to unicode
# qstr = input("Input a query: ")
#
# print("searching for ",qstr)
#
# ####################################
# # TODO: Build query parser and parse query
# ####################################
#
# with ix.searcher(weighting = scoring.TF_IDF()) as s:
#     qp = QueryParser("content", ix.schema)
#     user_q = qp.parse(qstr)
#
#     ####################################
#     # TODO: Search the content field
#     ####################################
#
#     results = s.search(user_q)
#     for hit in results:
#         print("cell {} of {}".format(hit["cell_no"], hit["filename"]))
#
#
#
# # -------------28----------------
# **********************JACKY: CELL TYPE =  markdown
# ## 3
# # -------------29----------------
# **********************JACKY: CELL TYPE =  code
# from whoosh.qparser import QueryParser
# from whoosh import scoring
#
# # Get input, convert to unicode
# qstr = input("Input a query: ")
#
# print("searching for ",qstr)
#
# ####################################
# # TODO: Build query parser and parse query
# ####################################
#
# with ix.searcher(weighting = scoring.TF_IDF()) as s:
#     qp = QueryParser("content", ix.schema)
#     user_q = qp.parse(qstr)
#
#     ####################################
#     # TODO: Search the content field
#     ####################################
#
#     results = s.search(user_q)
#     for hit in results:
#         print("cell {} of {}".format(hit["cell_no"], hit["filename"]))
#
#
#
# # -------------30----------------
# **********************JACKY: CELL TYPE =  markdown
# # SAVE YOUR NOTEBOOK

# %% [markdown]
# If you have followed the pattern of the way Dr. Scott builds up code...
#
# ## a) Time to create function!
#
# ### Your function should return a set of cells, each cell having all
# ### lines concatentated into one long `string` of data.
#
# The comment lines, `# TODO ... `, will define steps for you to complete.

# %%
def visibleTextFromNB(filename):
    '''
    # TODO Describe this function's purpose and return result
    
    This function pulls all the non-output visible cells from
    a JupyterNotebook and concatenates it all into a block of
    text.
    
    Returns : a list of the cells
    '''
    #####################################
    # TODO: Parse file, pull cells
    #####################################
    
    file_data = json.load(open(filename))
    cells = file_data.get('cells')
    
    #print('Dumping {} Non-output cells from {}'.format(len(cells), filename))
    
    cno = 1
    cell_list = []
    
    for c in cells:
        cell_type = c['cell_type']
        if (cell_type == 'code' or cell_type == 'markdown' or cell_type == 'raw'):
            #print("===========Cell Number: {}======{}========".format(cno, cell_type))
            
            source = c["source"]
            textBlock = ""
            
            for l in source:
                textBlock += l
            
            #print("appending # {} : {}".format(len(cell_list), textBlock[0:50]))
            cell_list.append(textBlock)
            cno += 1

            if cells == None:
                return cell_list
    
    # return the list
    return cell_list

#End of function: visibleTextFromNB

# %% [markdown]
# ## Test your function:

# %%
#################################
#        NO EDIT CELL
#################################

# Use the lab notebook
filename = '../labs/Text_Search_TFIDF.ipynb'
cells = visibleTextFromNB(filename)

# Print the begin and end
print(cells[0])
print(cells[1])
print('...')
print(cells[len(cells)-1])
# Out:
# # Building and Loading Text Search in Python Whoosh using TFIDF
#
#
# ## OUTLINE
#
#  1. [Task at hand](#task)
#  1. [Buiding our Whoosh Schema](#build_it)
#  1. [Loading Data](#load_it)
#  1. [Scoring](#Scoring)
#  1. [Executing Queries, Google-lite...very very lite](#TFIFD)
# ---
# <a id='task' ></a>
#
# ## Task at hand
#
# For this lab, we are going to revist the IR_with_Python_Whoosh lab in module 5 which walks us through the process of creating full text search capability within Python. In addition to that we are going to incorporate a scoring technique called TFIDF for ranking documents based on TFIDF scores of the terms occuring in the documents.
#
# We will walk through the process to build the search engine in Python using whoosh. We will compare the serach results with and without TFIDF method.
# ...
# The line_num above is the actual line number in the text file. docnum should be the index number in the whole indexes we have created.

# %% [markdown]
# #### <span style="background:yellow">Expected Output</span>
#
# ```
# # Building and Loading Text Search in Python Whoosh using TFIDF
#
#
# ## OUTLINE
#
#  1. [Task at hand](#task)
#  1. [Buiding our Whoosh Schema](#build_it)
#  1. [Loading Data](#load_it)
#  1. [Scoring](#Scoring)
#  1. [Executing Queries, Google-lite...very very lite](#TFIFD)
# ---
# <a id='task' ></a>
#
# ## Task at hand
#
# For this lab, we are going to revist the IR_with_Python_Whoosh lab in module 5 which walks us through the process of creating full text search capability within Python. In addition to that we are going to incorporate a scoring technique called TFIDF for ranking documents based on TFIDF scores of the terms occuring in the documents.
#
# We will walk through the process to build the search engine in Python using whoosh. We will compare the serach results with and without TFIDF method.
# ...
# The line_num above is the actual line number in the text file. docnum should be the index number in the whole indexes we have created.
# ```

# %% [markdown]
# # b) Create a _draft_ function to walk through directory and find notebooks (.ipynb)
#
# Collect up the directory walking code from module 5 examples.
#
# #### Note, the starting folder will be `'~'`, the alias for your home directory
#
# #### Note, do not process files yet, just construct the function and print the notebook path names

# %%
import os, os.path

def walkFolder(folder):
    '''
    Process a folder for files and subfolders
    Prints the files and folders that are processed. 
    '''
    # print('Processing folder: ', folder)
    
    #####################################
    # TODO: walk through the filesystem starting at folder
    # HINT: os.walk
    #####################################
    
    for root, dirs, files in os.walk(folder):
        # print("root = ", root)
        
        #####################################
        # TODO: Process Files
        # HINT: skips file.endswith("-checkpoint.ipynb")
        #####################################
        
        for file in files:
            if (file.endswith(".ipynb") \
                and not file.endswith("-checkpoint.ipynb")):
                filename = os.path.join(root, file)
                print("Found Notebook: ", filename)
           
        #####################################
        # TODO: Recurse into subfolders
        # HINT: Skip these
        #           .config
        #           .cache
        #           .ssh
        #           ... etc.         
        #####################################
        
        for d in dirs:
            if (d != ".config" \
                and d != ".cache" \
                and d != ".ssh" \
                and d != ".local" \
                and d != ".git" \
                and d != ".ipython"
               ):
                #print("recursing into :", d)
                walkFolder(d) 
    

############# END for walkFolder

# %% [markdown]
# ## Test your function:

# %%
#################################
#        NO EDIT CELL
#################################

# Use your top-level home directory
initial_root = os.path.expanduser('~') 

walkFolder("/dsa/home/lz6m7")
# Out:
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/module1.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/module2.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_numpy.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/Module_2_Lab_R_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/Module_2_Lab_Python_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/Intro_Numpy_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/practices/practice_descriptive_stats_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/practices/practice_descriptive_stats_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/practices/Practice_R_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/practices/Practice_Python_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/exercises/exercises_descriptive_stats_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/exercises/exercises_descriptive_stats_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/answers/practice_descriptive_stats_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/answers/practice_descriptive_stats_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/module3.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/labs/data_carpentry_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/labs/database_loading.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/labs/Module_3_R_Lab_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/labs/Module_3_Python_Lab_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/practices/python_carpentry_practice.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/practices/r_carpentry_practice.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/practices/Module_3_R_Practice_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/practices/Module_3_Python_Practice_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/exercises/data_carpentry_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/exercises/data_carpentry_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/answers/python_carpentry_practice.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module3/answers/r_carpentry_practice.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/module5.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/answers/ggplot2_plotting_practice.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/exercises/plotting_exercises_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/labs/ggplot2_intro_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/labs/ggplot2_theming.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/labs/Module_5_Lab_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/labs/Module_5_R_Theming_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/practices/ggplot2_plotting_practice.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module5/practices/Module_5_Practice_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/module6.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/labs/intro_decision_tree_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/labs/intro_naive_bayes_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/practices/practice_ml_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/practices/practice_ml_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/answers/practice_ml_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/answers/practice_ml_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/exercises/ml_exercises_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/exercises/ml_exercises_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module6/exercises/ml_exercises_python-Copy1.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module7/module7.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module7/labs/linear_regression_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module7/practices/regression_practice_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module7/answers/regression_practice_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module7/exercises/linear_regression_exercise_python.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module7/exercises/linear_regression_exercise_r.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module8/module8.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module8/storytelling-parts.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module8/exercises/python_story.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module8/exercises/r_story.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module8/labs/NFL_Story.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module8/labs/story_development_example.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module8/readings/websites.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/Course-Schedule.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M1-L2-ExploringSQLite.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M1-L3-ExploringPostgresSQL.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M2-L2-PostgreSQLAccess.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M2-L2-SQLite_LoadAccessUpdate.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M2-L3-PythonPostgreSQL.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M2-L3-PythonSQLite.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M3-L1-Joins.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M3-L2-Aggregations.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M3-L3-AdvancedAggregations.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M3-L4-WindowFunctions.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M3-L5-SubsetStatWindowFunctions.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M4-Final-GetAnswers.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M4-L1-DatabaseDesign.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-SQL_lz6m7/notebooks/M4-L4-DatabaseLoading.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/Course-Schedule.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L2-LoadData.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L3-LoadPackages.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L5-DataLoadingPandas.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L6-ControlStructures.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L7-BeautifulSoup.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L7-JSON_Parsing.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L8-UnivariateDataVisualization.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/00.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/01.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/02.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/03.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/04.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/05.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/06.ipynb
# Found Notebook:  /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/python_lectures/07.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module1/Module1.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module1/labs/Data_Cleaning.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module1/labs/Data_Extraction.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module1/labs/Web_Scrapping.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module1/labs/Data_Cleaning_JACKY.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module1/practices/Web_Scrapping.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module1/exercises/exercises.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/Module2.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/Practice/Practice_Glass.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/Practice/Practice_crime.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/labs/Visualizing_Association_Rules.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/labs/Association_Rules_and_Frequent_Pattern_Mining.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/Answers/Practice_crime_answers.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/Answers/Practice_groceries_answers.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/Answers/Practice_glass_answers.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/exercises/Exercises_Auto_Sales.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Module3.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/Hierarchical_Clustering.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/KMeans_Clustering.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Practices/Practice_DBSCAN.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Practices/Practice_Hierarchical.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Practices/Practice_Kmeans.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Exercises/Exercises.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Answers/Practice_DBSCAN.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Answers/Practice_Hierarchical_Clustering.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Answers/Practice_Kmeans.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module4/Module4.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module4/YouthSmoking - Association Mining and Anomaly Analysis.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module4/Data Exploration and flatten CSV output.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module4/labs/anomaly_detection.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/Module5.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/answers/Text_Preprocessing_Answers.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/exercises/Exercises_Python_text_search.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/labs/IR_with_PostgreSQL_full_text_search.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/labs/IR_with_Python_Whoosh.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/practices/Load_BookLines.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/practices/Text_Preprocessing.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/practices/Text_Preprocessing-Copy1.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/Module6.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb
# Found Notebook:  /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb

# %% [markdown]
# #### <span style="background:yellow">Expected Output</span>
#
#    * Expected output similar to
#
# ```
# Found Notebook: /dsa/home/scottgs/Testing Python.ipynb
# Found Notebook: /dsa/home/scottgs/Testing R.ipynb
# ...
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/practices/Text_Preprocessing.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/exercises/Exercises_Python_text_search.ipynb
# Found Notebook: /dsa/home/scottgs/sp17DMIR/modules/module5/answers/Text_Preprocessing_Answers.ipynb
# ```

# %% [markdown]
# # c) Create the schema for whoosh and initialize
# # the index in `notebooks` folder
#
# Recall, in the work above you pulled each visible cell from the notebook into a list of cells.
#
# So, we can store the data such as our results are:
#   * Filename
#   * Cell No.
#
# Then, we will also index the cell content.

# %%
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import StemmingAnalyzer
from whoosh import index


#####################################
# TODO: Create the schema
#####################################
schema = Schema(filename=ID(stored=True),
                cell_no=ID(stored=True),
                content=TEXT(analyzer=StemmingAnalyzer(), stored=True)
               )

#####################################
# TODO: Create the index and initialize a `writer`
#####################################
ix = index.create_in("indexes", schema)
writer = ix.writer()

# %%
#################################
#        NO EDIT CELL
#################################

#  REPEATED for better review

def visibleTextFromNB(filename):
    '''
    # TODO Describe this function's purpose and return result
    This function pulls all the non-output visible cells from
    a JupyterNotebook and concatenates it all into a block of
    text.
    Returns : a list of the cells
    '''
    #####################################
    # TODO: Parse file, pull cells
    #####################################

    file_data = json.load(open(filename))

    # File data is now a map, recall a JSON format is a combo of dictionaries and lists
    cells = file_data.get('cells')

    #####################################
    # TODO: Append cells into a list of cells
    # HINT: Do not strip the newline, \n
    #####################################

    cell_list = []
    if cells == None:
        return cell_list
    
    # for each cell in the notebook
    for c in cells:

        #extract and test the cell type
        cell_type = c['cell_type']
        if ('code'==cell_type or 'markdown'==cell_type or 'raw'==cell_type ):
            cell_text = ""
            # run the source into lines, it is actually a list of strings/lines
            source = c['source']
            for l in source:
                cell_text += l
            cell_list.append(cell_text)

            
    #####################################
    # TODO: Append cells into a list of cells
    # HINT: Do not strip the newline, \n
    #####################################

    # return the list
    return cell_list

#End of function: visibleTextFromNB

# %% [markdown]
# ## d) Write function to load file into the index
#   * See [Module 5 Lab](../../module5/labs/IR_with_Python_Whoosh.ipynb#This-should-look-familiar!)

# %%
def loadFile(writer, fname):
    '''
    Read file contents, load into database.
    '''
    #####################################
    # TODO: Get cell text from function
    #####################################
    cells = visibleTextFromNB(fname)
    
    cellnum = 1
    
    for c in cells:
        print("Starting file:", fname , " -- cellnum", cellnum)
        print("")
        
        writer.add_document(filename = fname, \
                            cell_no = str(cellnum), \
                            content = c)
        cellnum += 1     
    
    print("")
    print("Indexed: ", fname)
    print("==================")

# END of function

# %% [markdown]
# # e) Adapt the folder walking function to invoke file load
#
# ### HINT: add the `writer` as a parameter

# %%
import os, os.path

#####################################
# TODO: Adapt the parameters
#####################################
def walkFolder(writer, folder):
    '''
    Process a folder for files and subfolders
    Prints the files and folders that are processed. 
    '''
    for root, dirs, files in os.walk(folder):
        # print("root = ", root)
        
        #####################################
        # TODO: Process Files
        # HINT: skips file.endswith("-checkpoint.ipynb")
        #####################################
        
        for file in files:
            if (file.endswith(".ipynb") \
                and not file.endswith("-checkpoint.ipynb")):
                filename = os.path.join(root, file)
                loadFile(writer, filename)
                print("Found Notebook: ", filename)
                print("")
           
        #####################################
        # TODO: Recurse into subfolders
        # HINT: Skip these
        #           .config
        #           .cache
        #           .ssh
        #           ... etc.         
        #####################################
        
        for d in dirs:
            if (d != ".config" \
                and d != ".cache" \
                and d != ".ssh" \
                and d != ".local" \
                and d != ".git" \
                and d != ".ipython"
               ):
                #print("recursing into :", d)
                walkFolder(writer, d)           

############# END for walkFolder

# %% [markdown]
# # f) Run the index build

# %%
#################################
#        NO EDIT CELL
#################################

# Use your top-level home directory
initial_root = os.path.expanduser('~') 
walkFolder(writer,initial_root)


# Commit changes
writer.commit() # save changes
# Out:
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/module1.ipynb  -- cellnum 1
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/module1.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/module1.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb  -- cellnum 13
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_Python_Intro_DataScience_JACKY.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb  -- cellnum 32
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_python.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 33
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 34
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 35
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 36
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 37
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 38
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 39
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 40
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 41
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 42
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 43
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 44
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 45
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 46
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 47
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 48
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb  -- cellnum 49
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/intro_data_science_r.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb  -- cellnum 33
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/labs/Module1_R_Intro_DataScience_JACKY.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 33
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb  -- cellnum 34
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_python.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb  -- cellnum 33
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/practices/data_science_practice_r.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb  -- cellnum 33
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_python.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb  -- cellnum 32
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/answers/data_science_practice_r_answers.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb  -- cellnum 16
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_python.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb  -- cellnum 14
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module1/exercises/intro_data_science_exercise_r.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/module2.ipynb  -- cellnum 1
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/module2.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/module2.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 33
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 34
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 35
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 36
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb  -- cellnum 37
#
#
# Indexed:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_python.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 33
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 34
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 35
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 36
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 37
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 38
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 39
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 40
#
# Starting file: /dsa/home/lz6m7/sp17dsa7600_lz6m7/modules/module2/labs/intro_descriptive_stats_r.ipynb  -- cellnum 41
#
# ...
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb  -- cellnum 22
#
#
# Indexed:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb  -- cellnum 11
#
#
# Indexed:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb  -- cellnum 30
#
#
# Indexed:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb  -- cellnum 30
#
#
# Indexed:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 1
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 2
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 3
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 4
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 5
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 6
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 7
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 8
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 9
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 10
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 11
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 12
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 13
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 14
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 15
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 16
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 17
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 18
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 19
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 20
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 21
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 22
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 23
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 24
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 25
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 26
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 27
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 28
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 29
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 30
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 31
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 32
#
# Starting file: /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb  -- cellnum 33
#
#
# Indexed:  /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb
# ==================
# Found Notebook:  /dsa/home/lz6m7/DSA-8640_lz6m7/modules/module1/exercises/breach_report_exercise.ipynb

# %%
# DO NOT RUN UNLESS YOU NEED A RESET

# from whoosh import writing
# writer.commit(mergetype=writing.CLEAR)

# %% [markdown]
# # g) Execute three queries
#
# ## 1

# %%
from whoosh.qparser import QueryParser
from whoosh import scoring

# Get input, convert to unicode
qstr = input("Input a query: ")

print("searching for ",qstr)

####################################
# TODO: Build query parser and parse query
####################################

with ix.searcher(weighting = scoring.TF_IDF()) as s:
    qp = QueryParser("content", ix.schema)
    user_q = qp.parse(qstr)

    ####################################
    # TODO: Search the content field
    ####################################
    
    results = s.search(user_q)
    for hit in results:
        print("cell {} of {}".format(hit["cell_no"], hit["filename"]))
# Out:
# Input a query: QueryParser
# searching for  QueryParser
# cell 26 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb
# cell 26 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine-Copy1.ipynb
# cell 14 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/exercises/Exercises_Python_text_search.ipynb
# cell 11 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module5/labs/IR_with_Python_Whoosh.ipynb
# cell 9 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb
# cell 14 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb
# cell 17 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/labs/Text_Search_TFIDF.ipynb
# cell 8 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb
# cell 9 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/practices/Text_Search_TFIDF_Practice.ipynb
# cell 25 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb

# %% [markdown]
# #### <span style="background:yellow">Expected Output</span>
#
#   *  Example output from searching for QueryParser
#
# ```
# Input a qeury: QueryParser
# searching for  QueryParser
# content:queryparser
# Cell 11 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# Cell 27 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module5/answers/ParsingWikipediaLifeformPage.ipynb'
# Cell 25 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/exercises/DSA_Notebook_Search_Engine.ipynb'
# Cell 9 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 14 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 17 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Text_Search_TFIDF.ipynb'
# Cell 45 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/labs/Topic_modelling.ipynb'
# Cell 7 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 8 of Notebook '/dsa/home/scottgs/DataMiningAndInfoRetrieval/modules/module6/answers/TFIDF_Scoring_Practice.ipynb'
# Cell 11 of Notebook '/dsa/home/scottgs/sp17DMIR/modules/module5/labs/IR_with_Python_Whoosh.ipynb'
# ```
#
# ---
# ## 2

# %%
from whoosh.qparser import QueryParser
from whoosh import scoring

# Get input, convert to unicode
qstr = input("Input a query: ")

print("searching for ",qstr)

####################################
# TODO: Build query parser and parse query
####################################

with ix.searcher(weighting = scoring.TF_IDF()) as s:
    qp = QueryParser("content", ix.schema)
    user_q = qp.parse(qstr)

    ####################################
    # TODO: Search the content field
    ####################################
    
    results = s.search(user_q)
    for hit in results:
        print("cell {} of {}".format(hit["cell_no"], hit["filename"]))
# Out:
# Input a query: Clusters
# searching for  Clusters
# cell 1 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 2 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/KMeans_Clustering.ipynb
# cell 10 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/Hierarchical_Clustering.ipynb
# cell 15 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 21 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 36 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/Hierarchical_Clustering.ipynb
# cell 32 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Practices/Practice_DBSCAN.ipynb
# cell 27 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Answers/Practice_DBSCAN.ipynb
# cell 12 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/Hierarchical_Clustering.ipynb
# cell 23 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/KMeans_Clustering.ipynb

# %% [markdown]
# ## 3

# %%
from whoosh.qparser import QueryParser
from whoosh import scoring

# Get input, convert to unicode
qstr = input("Input a query: ")

print("searching for ",qstr)

####################################
# TODO: Build query parser and parse query
####################################

with ix.searcher(weighting = scoring.TF_IDF()) as s:
    qp = QueryParser("content", ix.schema)
    user_q = qp.parse(qstr)

    ####################################
    # TODO: Search the content field
    ####################################
    
    results = s.search(user_q)
    for hit in results:
        print("cell {} of {}".format(hit["cell_no"], hit["filename"]))
# Out:
# Input a query: Milk
# searching for  Milk
# cell 36 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 1 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/labs/Association_Rules_and_Frequent_Pattern_Mining.ipynb
# cell 28 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 35 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 4 of /dsa/home/lz6m7/BC-Python_lz6m7/notebooks/L7-BeautifulSoup.ipynb
# cell 4 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module2/labs/Visualizing_Association_Rules.ipynb
# cell 29 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 43 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 44 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb
# cell 47 of /dsa/home/lz6m7/sp17DMIR_lz6m7/modules/module3/Labs/DBSCAN_Clustering.ipynb

# %% [markdown]
# # SAVE YOUR NOTEBOOK
